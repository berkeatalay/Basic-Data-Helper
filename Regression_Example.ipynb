# %%
from Process_Classes import  information, data_regression

# %%
df = information("data/","HW_Data_Set.xlsx")
# Out:
# Class object initialized

# %%
df.get_inf(True,"drop")
# Out:
# HW_Data_Set.xlsx is loaded
# 6167
# 6167
#    ind_5  ind_6  ind_8      ind_9     ind_10     ind_12     ind_13  ind_14  \
# 0     19     17  100.0  85.714286  14.285714  72.363515  60.808814   23.80
# 1     24     19  100.0  78.571429  21.428571  74.275883  64.366798   11.45
# 2     30     24  100.0  71.428571  28.571429  75.140402  65.915803    8.75
# 3     37     30  100.0  64.285714  35.714286  76.677846  68.584234    7.80
# 4     41     37  100.0  57.142857  42.857143  81.603007  76.455495   14.90
#
#    ind_15  ind_16  ...  ind_416  ind_418  ind_420  ind_422  ind_424   ind_426  \
# 0   17.62   11.73  ...    -49.6      -54     -152     -353      1.0  0.498547
# 1   18.16   12.22  ...    -55.6      -60     -158     -359      1.0  0.537088
# 2   17.86   12.28  ...    -58.4      -60     -160     -362      1.0  0.615169
# 3   14.76   12.61  ...    -61.8      -65     -166     -367      1.0  0.661517
# 4   11.92   14.25  ...    -79.8      -86     -186     -388      1.0  0.747204
#
# ...

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
df.dropcolumn(["ind_420","ind_422"])

# %%
df.dropcolumn(["20_target","90_target"])

# %%
df.cattodummy()
# Out:
# Looking for: ['ind_109']
# Adding columns:  ['ind_109_GREEN', 'ind_109_RED']
# Dummies entered as .catdata
#    ind_5  ind_6  ind_8      ind_9     ind_10     ind_12     ind_13  ind_14  \
# 0     19     17  100.0  85.714286  14.285714  72.363515  60.808814   23.80
# 1     24     19  100.0  78.571429  21.428571  74.275883  64.366798   11.45
# 2     30     24  100.0  71.428571  28.571429  75.140402  65.915803    8.75
# 3     37     30  100.0  64.285714  35.714286  76.677846  68.584234    7.80
# 4     41     37  100.0  57.142857  42.857143  81.603007  76.455495   14.90
#
#    ind_15  ind_16  ...   ind_412  ind_414  ind_416  ind_418  ind_424  \
# 0   17.62   11.73  ...  0.002371      2.0    -49.6      -54      1.0
# 1   18.16   12.22  ...  0.003074      0.8    -55.6      -60      1.0
# 2   17.86   12.28  ...  0.003561      2.7    -58.4      -60      1.0
# 3   14.76   12.61  ...  0.004366      0.9    -61.8      -65      1.0
# ...

# %%
y,X= df.choose_your_y("50_target")
# Out:
#    ind_5  ind_6  ind_8      ind_9     ind_10     ind_12     ind_13  ind_14  \
# 0     19     17  100.0  85.714286  14.285714  72.363515  60.808814   23.80
# 1     24     19  100.0  78.571429  21.428571  74.275883  64.366798   11.45
# 2     30     24  100.0  71.428571  28.571429  75.140402  65.915803    8.75
# 3     37     30  100.0  64.285714  35.714286  76.677846  68.584234    7.80
# 4     41     37  100.0  57.142857  42.857143  81.603007  76.455495   14.90
#
#    ind_15  ind_16  ...  ind_410   ind_412  ind_414  ind_416  ind_418  ind_424  \
# 0   17.62   11.73  ...      -27  0.002371      2.0    -49.6      -54      1.0
# 1   18.16   12.22  ...      -31  0.003074      0.8    -55.6      -60      1.0
# 2   17.86   12.28  ...      -30  0.003561      2.7    -58.4      -60      1.0
# 3   14.76   12.61  ...      -30  0.004366      0.9    -61.8      -65      1.0
# 4   11.92   14.25  ...      -45  0.004198      0.1    -79.8      -86      1.0
#
# ...

# %%
X = X.drop("ind_109_RED",axis=1)

# %%
a = data_regression(X,y)
# Out:
# Regression class

# %%
a.split(42,False)

# %%
a.x.isna().sum().sort_values()
# Out:
# ind_5            0
# ind_311          0
# ind_310          0
# ind_309          0
# ind_243          0
#                 ..
# ind_45           0
# ind_44           0
# ind_43           0
# ind_41           0
# ind_109_GREEN    0
# Length: 131, dtype: int64

# %%
a.default_processes()
# Out:
# Results for default LinearRegression
# 50.108076357042314
# Results for default decision tree
# 46.27459862115547
# Results for default random forest
# 35.34614801723616
# Results for default MLP
# 52.434198887428536
# Results for default Gradient Boosting
# 52.434198887428536
# Results for default Gradient Boosting
# 44.159011575257416
# Results for default XGBoost
# 39.20827261120345
# Results for default LGBM
# 37.76433257980274
# Results for default CatBoost
# 37.90249521366632
# Results for default KNeighborsRegressor
# 38.9558193522356

# %%
a.grid('cat')
# Out:
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   24.6s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed: 20.5min finished
# En iyi parametlerler: {'depth': 3, 'iterations': 200, 'learning_rate': 0.01}
# Result for  cat
# 34.5953666645919

# %%
a.grid('xgb')
# Out:
# Fitting 10 folds for each of 384 candidates, totalling 3840 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   40.6s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed: 18.7min
# [Parallel(n_jobs=-1)]: Done 632 tasks      | elapsed: 36.4min
# [Parallel(n_jobs=-1)]: Done 997 tasks      | elapsed: 60.1min
# [Parallel(n_jobs=-1)]: Done 1442 tasks      | elapsed: 88.0min
# [Parallel(n_jobs=-1)]: Done 1969 tasks      | elapsed: 120.9min
# [Parallel(n_jobs=-1)]: Done 2576 tasks      | elapsed: 180.1min
# [Parallel(n_jobs=-1)]: Done 3265 tasks      | elapsed: 251.4min
# [Parallel(n_jobs=-1)]: Done 3840 out of 3840 | elapsed: 319.6min finished
# En iyi parametlerler: {'colsample_bytree': 0.6, 'learning_rate': 0.01, 'max_depth': 5, 'min_child_weight': 0.8, 'n_estimators': 100}
# Result for  xgb
# 35.04715556948948

# %%
a.grid('knn')
# Out:
# Fitting 5 folds for each of 234 candidates, totalling 1170 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:   18.6s
# [Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed:   45.4s
# [Parallel(n_jobs=-1)]: Done 632 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 997 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 1170 out of 1170 | elapsed:  2.8min finished
# En iyi parametlerler: {'metric': 'manhattan', 'n_neighbors': 39, 'weights': 'uniform'}
# Result for  knn
# 38.9558193522356

# %% [markdown]
# HW4_Regressiondakin diğer değerlere de baktığımız zaman en iyi sonucun catboostun tuned halinde gözlemliyoruz
